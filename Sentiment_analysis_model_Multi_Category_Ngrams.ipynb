# %% [markdown]
# <a href="https://colab.research.google.com/github/Sereniiti/ai-models/blob/main/Sentiment_analysis_model_Multi_Category_Ngrams.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import re
import string
from string import punctuation
import nltk
from nltk.corpus import stopwords

# %%
nltk.download ("stopwords")

import matplotlib.pyplot as plt
# !pip install sklearn
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn) (0.22.2.post1)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.19.5)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.0.1)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Training data (sentences) - Dataset.csv')
df.head ()
# Out:
#                                                   en  ... Comment
# 0  A 2014 study examined the effects of combined ...  ...     NaN
# 1                                     Boys don't cry  ...     NaN
# 2  A cheetah, the fastest land animal, can run 70...  ...     NaN
# 3  A combination of words that makes sense is cal...  ...     NaN
# 4           A door would have more charisma than you  ...     NaN
#
# [5 rows x 7 columns]

# %%
df=df.drop(['fr', 'Step', 'Tips in the steps (WIP)', 'Alert', 'Comment',],axis=1)
df.dropna(inplace=True)

# %%
df
# Out:
#                                                       en  rating
# 0      A 2014 study examined the effects of combined ...       4
# 1                                         Boys don't cry       2
# 2      A cheetah, the fastest land animal, can run 70...       4
# 3      A combination of words that makes sense is cal...       4
# 4               A door would have more charisma than you       0
# ...                                                  ...     ...
# 10988          it was violent and gratuitous it was mean       1
# 10989  You say that but I assure you that in normal c...       1
# 10990                            You really went too far       1
# 10991                                        It was mean       1
# 10992                   you lie like most people breathe       1
#
# [10993 rows x 2 columns]

# %%
df ['Violence_Rating']=df ['rating'].apply(lambda x: 'Non_violent' if x > 4 else ('Neutral' if x ==4 else 'Violent'))

# %%
sns.set_style ('whitegrid')
sns.countplot (x='Violence_Rating', data=df, palette='summer')

# %%
def get_text_processing(text):
    stpword = ['the','a', 'an']
    no_punctuation = [char for char in text if char not in string.punctuation]
    no_punctuation = ''.join(no_punctuation)
    return ' '.join([word for word in no_punctuation.split() if word.lower() not in stpword])

# %%
df['en_processed'] = df['en'].apply(get_text_processing)
df.head()
# Out:
#                                                   en  ...                                       en_processed
# 0  A 2014 study examined the effects of combined ...  ...  2014 study examined effects of combined NVC an...
# 1                                     Boys don't cry  ...                                      Boys dont cry
# 2  A cheetah, the fastest land animal, can run 70...  ...  cheetah fastest land animal can run 70 miles hour
# 3  A combination of words that makes sense is cal...  ...  combination of words that makes sense is calle...
# 4           A door would have more charisma than you  ...             door would have more charisma than you
#
# [5 rows x 4 columns]

# %%
df = df[['en_processed', 'Violence_Rating']]
df.head()
# Out:
#                                         en_processed Violence_Rating
# 0  2014 study examined effects of combined NVC an...         Neutral
# 1                                      Boys dont cry         Violent
# 2  cheetah fastest land animal can run 70 miles hour         Neutral
# 3  combination of words that makes sense is calle...         Neutral
# 4             door would have more charisma than you         Violent

# %%
one_hot = pd.get_dummies(df["Violence_Rating"])
df.drop(["Violence_Rating"], axis=1, inplace=True)
df = pd.concat([df, one_hot], axis=1)

dft = df.sample (n=10000, random_state=100)
dfr = df.drop (dft.index)
dfr
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                                             en_processed  ...  Violent
# 2      cheetah fastest land animal can run 70 miles hour  ...        0
# 6      group of words which makes complete sense is c...  ...        0
# 7                     little hello and kiss from our son  ...        0
# 18     According to this article volcanoes in Auvergn...  ...        0
# 32     After long hot night we spent together I feel ...  ...        0
# ...                                                  ...  ...      ...
# 10863                       I am only doing this for you  ...        1
# 10897                             You should go out more  ...        1
# 10917  You think you dont need anyone but in fact you...  ...        1
# 10963                         I love you as big as truck  ...        0
# 10983                          Wow youre really annoying  ...        1
#
# [993 rows x 4 columns]

# %%
dft
# Out:
#                                            en_processed  ...  Violent
# 3305                         Im good at English grammar  ...        0
# 5410  We have received confirmation that this attack...  ...        0
# 7475                     You think youre alone in world  ...        1
# 4573  Now that I know that I am selected I feel much...  ...        0
# 1139  He thinks hes only one with something interest...  ...        1
# ...                                                 ...  ...      ...
# 2502              I love you much more than you love me  ...        1
# 6304                           You are not good husband  ...        1
# 3733                     Im really unhappy with my life  ...        0
# 3178                              Im feeling very tired  ...        0
# 6097                          You are little street rat  ...        1
#
# [10000 rows x 4 columns]

# %%
X1 = dft["en_processed"].values
X2= dfr["en_processed"].values
X3= dfr["en_processed"].values
Y1= dft.drop("en_processed", axis=1).values
Y2= dfr.drop("en_processed", axis=1).values
X1_train, X1_test, Y1_train, Y1_test=train_test_split(X1,Y1, test_size=0.30, random_state=42)

# %%
dfffff = pd.DataFrame (X3)
dfffff
# Out:
#                                                      0
# 0    cheetah fastest land animal can run 70 miles hour
# 1    group of words which makes complete sense is c...
# 2                   little hello and kiss from our son
# 3    According to this article volcanoes in Auvergn...
# 4    After long hot night we spent together I feel ...
# ..                                                 ...
# 988                       I am only doing this for you
# 989                             You should go out more
# 990  You think you dont need anyone but in fact you...
# 991                         I love you as big as truck
# 992                          Wow youre really annoying
#
# [993 rows x 1 columns]

# %%
vect = CountVectorizer(analyzer='word', ngram_range=(1, 3))
X1_train = vect.fit_transform (X1_train)
X1_test = vect.transform(X1_test)
X2= vect.transform(X2)
X2
# Out:
# <993x58405 sparse matrix of type '<class 'numpy.int64'>'
# 	with 11944 stored elements in Compressed Sparse Row format>

# %%
tfidf = TfidfTransformer()
X1_train = tfidf.fit_transform(X1_train)
X1_test = tfidf.transform(X1_test)
X1_train = X1_train.toarray()
X1_test = X1_test.toarray()
X2= tfidf.fit_transform (X2)
X2= X2.toarray ()

# %%
model = Sequential()
model.add(Dense(units=20, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(units=20, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(units=20, activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(units=3, activation="softmax"))
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss="categorical_crossentropy", optimizer='adam', metrics=["accuracy"])
early_stop = EarlyStopping(monitor="val_loss", mode="min", verbose=1, patience=2)

# %%
model.fit(
    x=X1_train,
    y=Y1_train,
    batch_size=10,
    epochs=200,
    validation_data=(X1_test, Y1_test),
    verbose=1,
)
# Out:
# Epoch 1/200
# 700/700 [==============================] - 8s 10ms/step - loss: 0.8655 - accuracy: 0.5941 - val_loss: 0.5665 - val_accuracy: 0.7850
# Epoch 2/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.5383 - accuracy: 0.7983 - val_loss: 0.4971 - val_accuracy: 0.7963
# Epoch 3/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.3809 - accuracy: 0.8539 - val_loss: 0.5025 - val_accuracy: 0.8003
# Epoch 4/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.2902 - accuracy: 0.8759 - val_loss: 0.5369 - val_accuracy: 0.8053
# Epoch 5/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.2316 - accuracy: 0.9031 - val_loss: 0.5919 - val_accuracy: 0.8517
# Epoch 6/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.1850 - accuracy: 0.9330 - val_loss: 0.6507 - val_accuracy: 0.8537
# Epoch 7/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.1614 - accuracy: 0.9380 - val_loss: 0.6852 - val_accuracy: 0.8487
# Epoch 8/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.1376 - accuracy: 0.9527 - val_loss: 0.8170 - val_accuracy: 0.8463
# Epoch 9/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.1139 - accuracy: 0.9606 - val_loss: 0.8658 - val_accuracy: 0.8517
# Epoch 10/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.1104 - accuracy: 0.9627 - val_loss: 0.9148 - val_accuracy: 0.8487
# Epoch 11/200
# 700/700 [==============================] - 7s 9ms/step - loss: 0.0896 - accuracy: 0.9674 - val_loss: 1.0873 - val_accuracy: 0.8507
# Epoch 12/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0990 - accuracy: 0.9666 - val_loss: 1.0293 - val_accuracy: 0.8500
# Epoch 13/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0898 - accuracy: 0.9683 - val_loss: 1.0288 - val_accuracy: 0.8480
# Epoch 14/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0893 - accuracy: 0.9679 - val_loss: 1.0997 - val_accuracy: 0.8480
# Epoch 15/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0736 - accuracy: 0.9701 - val_loss: 1.2997 - val_accuracy: 0.8503
# Epoch 16/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0926 - accuracy: 0.9677 - val_loss: 1.2005 - val_accuracy: 0.8500
# Epoch 17/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0819 - accuracy: 0.9700 - val_loss: 1.2370 - val_accuracy: 0.8510
# Epoch 18/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0716 - accuracy: 0.9731 - val_loss: 1.5040 - val_accuracy: 0.8477
# Epoch 19/200
# 700/700 [==============================] - 7s 10ms/step - loss: 0.0716 - accuracy: 0.9743 - val_loss: 1.4614 - val_accuracy: 0.8480
# Epoch 20/200
# 700/700 [==============================] - 7s 9ms/step - loss: 0.0681 - accuracy: 0.9731 - val_loss: 1.4822 - val_accuracy: 0.8463
# Epoch 21/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0738 - accuracy: 0.9730 - val_loss: 1.5625 - val_accuracy: 0.8483
# Epoch 22/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0680 - accuracy: 0.9736 - val_loss: 1.6057 - val_accuracy: 0.8520
# Epoch 23/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0644 - accuracy: 0.9741 - val_loss: 1.8090 - val_accuracy: 0.8493
# Epoch 24/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0576 - accuracy: 0.9756 - val_loss: 1.8004 - val_accuracy: 0.8460
# Epoch 25/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0709 - accuracy: 0.9729 - val_loss: 1.8474 - val_accuracy: 0.8477
# Epoch 26/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0663 - accuracy: 0.9739 - val_loss: 1.9816 - val_accuracy: 0.8460
# Epoch 27/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0664 - accuracy: 0.9749 - val_loss: 2.0553 - val_accuracy: 0.8500
# Epoch 28/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0618 - accuracy: 0.9731 - val_loss: 2.1176 - val_accuracy: 0.8483
# Epoch 29/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0575 - accuracy: 0.9789 - val_loss: 2.2807 - val_accuracy: 0.8507
# Epoch 30/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0604 - accuracy: 0.9789 - val_loss: 2.1791 - val_accuracy: 0.8500
# Epoch 31/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0617 - accuracy: 0.9746 - val_loss: 2.2533 - val_accuracy: 0.8497
# Epoch 32/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0616 - accuracy: 0.9756 - val_loss: 2.3165 - val_accuracy: 0.8460
# Epoch 33/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0740 - accuracy: 0.9726 - val_loss: 2.2202 - val_accuracy: 0.8457
# Epoch 34/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0593 - accuracy: 0.9761 - val_loss: 2.4549 - val_accuracy: 0.8467
# Epoch 35/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0599 - accuracy: 0.9744 - val_loss: 2.4384 - val_accuracy: 0.8443
# Epoch 36/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0618 - accuracy: 0.9760 - val_loss: 2.6549 - val_accuracy: 0.8447
# Epoch 37/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0511 - accuracy: 0.9780 - val_loss: 2.7270 - val_accuracy: 0.8467
# Epoch 38/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0613 - accuracy: 0.9761 - val_loss: 2.5084 - val_accuracy: 0.8427
# Epoch 39/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0586 - accuracy: 0.9734 - val_loss: 2.5765 - val_accuracy: 0.8460
# Epoch 40/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0592 - accuracy: 0.9774 - val_loss: 2.7070 - val_accuracy: 0.8437
# Epoch 41/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0532 - accuracy: 0.9769 - val_loss: 2.8345 - val_accuracy: 0.8447
# Epoch 42/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0593 - accuracy: 0.9774 - val_loss: 2.6483 - val_accuracy: 0.8473
# Epoch 43/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0526 - accuracy: 0.9783 - val_loss: 2.8801 - val_accuracy: 0.8500
# Epoch 44/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0473 - accuracy: 0.9806 - val_loss: 3.0324 - val_accuracy: 0.8460
# Epoch 45/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0575 - accuracy: 0.9774 - val_loss: 2.9398 - val_accuracy: 0.8463
# Epoch 46/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0524 - accuracy: 0.9774 - val_loss: 3.0408 - val_accuracy: 0.8483
# Epoch 47/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0542 - accuracy: 0.9797 - val_loss: 3.1563 - val_accuracy: 0.8457
# Epoch 48/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0516 - accuracy: 0.9776 - val_loss: 3.0910 - val_accuracy: 0.8437
# Epoch 49/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0534 - accuracy: 0.9761 - val_loss: 3.5470 - val_accuracy: 0.8477
# Epoch 50/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0495 - accuracy: 0.9783 - val_loss: 3.6239 - val_accuracy: 0.8433
# Epoch 51/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0571 - accuracy: 0.9769 - val_loss: 3.3403 - val_accuracy: 0.8483
# Epoch 52/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0540 - accuracy: 0.9767 - val_loss: 3.2746 - val_accuracy: 0.8443
# Epoch 53/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0621 - accuracy: 0.9773 - val_loss: 3.3301 - val_accuracy: 0.8460
# Epoch 54/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0522 - accuracy: 0.9789 - val_loss: 3.5674 - val_accuracy: 0.8463
# Epoch 55/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0525 - accuracy: 0.9777 - val_loss: 3.5230 - val_accuracy: 0.8477
# Epoch 56/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0525 - accuracy: 0.9767 - val_loss: 3.5435 - val_accuracy: 0.8460
# Epoch 57/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0466 - accuracy: 0.9797 - val_loss: 3.7318 - val_accuracy: 0.8450
# Epoch 58/200
# 700/700 [==============================] - 7s 10ms/step - loss: 0.0579 - accuracy: 0.9810 - val_loss: 3.4340 - val_accuracy: 0.8430
# Epoch 59/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0522 - accuracy: 0.9806 - val_loss: 3.6633 - val_accuracy: 0.8437
# Epoch 60/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0501 - accuracy: 0.9794 - val_loss: 3.6998 - val_accuracy: 0.8447
# Epoch 61/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0466 - accuracy: 0.9803 - val_loss: 3.8257 - val_accuracy: 0.8440
# Epoch 62/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0518 - accuracy: 0.9751 - val_loss: 3.8286 - val_accuracy: 0.8410
# Epoch 63/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0521 - accuracy: 0.9779 - val_loss: 3.7991 - val_accuracy: 0.8423
# Epoch 64/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0516 - accuracy: 0.9776 - val_loss: 4.1010 - val_accuracy: 0.8380
# Epoch 65/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0518 - accuracy: 0.9797 - val_loss: 4.4399 - val_accuracy: 0.8343
# Epoch 66/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0495 - accuracy: 0.9770 - val_loss: 4.4007 - val_accuracy: 0.8407
# Epoch 67/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0519 - accuracy: 0.9784 - val_loss: 4.8340 - val_accuracy: 0.8350
# Epoch 68/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0557 - accuracy: 0.9783 - val_loss: 4.3497 - val_accuracy: 0.8497
# Epoch 69/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0561 - accuracy: 0.9761 - val_loss: 4.3084 - val_accuracy: 0.8437
# Epoch 70/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0556 - accuracy: 0.9777 - val_loss: 4.4348 - val_accuracy: 0.8413
# Epoch 71/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0477 - accuracy: 0.9811 - val_loss: 4.5564 - val_accuracy: 0.8413
# Epoch 72/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0499 - accuracy: 0.9786 - val_loss: 4.6507 - val_accuracy: 0.8433
# Epoch 73/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0583 - accuracy: 0.9739 - val_loss: 4.4056 - val_accuracy: 0.8403
# Epoch 74/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0455 - accuracy: 0.9807 - val_loss: 4.4346 - val_accuracy: 0.8343
# Epoch 75/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0488 - accuracy: 0.9784 - val_loss: 4.7652 - val_accuracy: 0.8427
# Epoch 76/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0490 - accuracy: 0.9776 - val_loss: 4.9183 - val_accuracy: 0.8430
# Epoch 77/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0524 - accuracy: 0.9773 - val_loss: 4.9559 - val_accuracy: 0.8407
# Epoch 78/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0481 - accuracy: 0.9786 - val_loss: 5.2627 - val_accuracy: 0.8477
# Epoch 79/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0484 - accuracy: 0.9787 - val_loss: 5.1400 - val_accuracy: 0.8460
# Epoch 80/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0437 - accuracy: 0.9814 - val_loss: 5.2155 - val_accuracy: 0.8413
# Epoch 81/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0519 - accuracy: 0.9783 - val_loss: 5.1549 - val_accuracy: 0.8413
# Epoch 82/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0611 - accuracy: 0.9784 - val_loss: 5.1535 - val_accuracy: 0.8387
# Epoch 83/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0454 - accuracy: 0.9790 - val_loss: 5.2756 - val_accuracy: 0.8403
# Epoch 84/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0543 - accuracy: 0.9803 - val_loss: 5.1524 - val_accuracy: 0.8383
# Epoch 85/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0442 - accuracy: 0.9810 - val_loss: 5.7211 - val_accuracy: 0.8473
# Epoch 86/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0515 - accuracy: 0.9811 - val_loss: 5.2092 - val_accuracy: 0.8377
# Epoch 87/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0514 - accuracy: 0.9780 - val_loss: 5.6404 - val_accuracy: 0.8457
# Epoch 88/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0397 - accuracy: 0.9820 - val_loss: 5.7971 - val_accuracy: 0.8427
# Epoch 89/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0512 - accuracy: 0.9764 - val_loss: 5.7768 - val_accuracy: 0.8463
# Epoch 90/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0395 - accuracy: 0.9850 - val_loss: 6.0034 - val_accuracy: 0.8420
# Epoch 91/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0453 - accuracy: 0.9826 - val_loss: 5.7434 - val_accuracy: 0.8397
# Epoch 92/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0484 - accuracy: 0.9791 - val_loss: 5.4069 - val_accuracy: 0.8393
# Epoch 93/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0456 - accuracy: 0.9790 - val_loss: 5.6986 - val_accuracy: 0.8393
# Epoch 94/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0479 - accuracy: 0.9796 - val_loss: 5.8180 - val_accuracy: 0.8407
# Epoch 95/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0410 - accuracy: 0.9827 - val_loss: 6.1305 - val_accuracy: 0.8417
# Epoch 96/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0468 - accuracy: 0.9790 - val_loss: 6.0039 - val_accuracy: 0.8403
# Epoch 97/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0520 - accuracy: 0.9787 - val_loss: 5.9040 - val_accuracy: 0.8420
# Epoch 98/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0516 - accuracy: 0.9776 - val_loss: 6.1634 - val_accuracy: 0.8387
# Epoch 99/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0460 - accuracy: 0.9784 - val_loss: 6.4627 - val_accuracy: 0.8357
# Epoch 100/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0472 - accuracy: 0.9819 - val_loss: 6.4005 - val_accuracy: 0.8403
# Epoch 101/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0462 - accuracy: 0.9807 - val_loss: 6.3674 - val_accuracy: 0.8403
# Epoch 102/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0439 - accuracy: 0.9820 - val_loss: 6.3831 - val_accuracy: 0.8417
# Epoch 103/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0498 - accuracy: 0.9801 - val_loss: 6.6162 - val_accuracy: 0.8370
# Epoch 104/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0494 - accuracy: 0.9803 - val_loss: 6.6192 - val_accuracy: 0.8383
# Epoch 105/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0583 - accuracy: 0.9789 - val_loss: 6.3565 - val_accuracy: 0.8387
# Epoch 106/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0514 - accuracy: 0.9801 - val_loss: 6.5311 - val_accuracy: 0.8353
# Epoch 107/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0434 - accuracy: 0.9813 - val_loss: 6.8358 - val_accuracy: 0.8373
# Epoch 108/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0432 - accuracy: 0.9790 - val_loss: 6.9365 - val_accuracy: 0.8433
# Epoch 109/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0569 - accuracy: 0.9793 - val_loss: 6.4922 - val_accuracy: 0.8363
# Epoch 110/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0439 - accuracy: 0.9804 - val_loss: 6.7553 - val_accuracy: 0.8403
# Epoch 111/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0507 - accuracy: 0.9777 - val_loss: 6.7794 - val_accuracy: 0.8413
# Epoch 112/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0515 - accuracy: 0.9814 - val_loss: 6.4647 - val_accuracy: 0.8373
# Epoch 113/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0421 - accuracy: 0.9801 - val_loss: 6.2899 - val_accuracy: 0.8330
# Epoch 114/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0499 - accuracy: 0.9816 - val_loss: 6.4869 - val_accuracy: 0.8393
# Epoch 115/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0438 - accuracy: 0.9796 - val_loss: 6.4256 - val_accuracy: 0.8377
# Epoch 116/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0425 - accuracy: 0.9797 - val_loss: 6.7774 - val_accuracy: 0.8390
# Epoch 117/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0438 - accuracy: 0.9806 - val_loss: 7.1555 - val_accuracy: 0.8417
# Epoch 118/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0468 - accuracy: 0.9806 - val_loss: 6.9842 - val_accuracy: 0.8397
# Epoch 119/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0427 - accuracy: 0.9820 - val_loss: 7.0580 - val_accuracy: 0.8340
# Epoch 120/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0425 - accuracy: 0.9791 - val_loss: 7.3484 - val_accuracy: 0.8400
# Epoch 121/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0494 - accuracy: 0.9814 - val_loss: 7.2312 - val_accuracy: 0.8397
# Epoch 122/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0437 - accuracy: 0.9813 - val_loss: 7.7122 - val_accuracy: 0.8437
# Epoch 123/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0440 - accuracy: 0.9814 - val_loss: 7.6019 - val_accuracy: 0.8383
# Epoch 124/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0436 - accuracy: 0.9806 - val_loss: 7.7884 - val_accuracy: 0.8377
# Epoch 125/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0411 - accuracy: 0.9817 - val_loss: 7.9146 - val_accuracy: 0.8347
# Epoch 126/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0423 - accuracy: 0.9801 - val_loss: 8.0539 - val_accuracy: 0.8350
# Epoch 127/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0503 - accuracy: 0.9760 - val_loss: 8.1359 - val_accuracy: 0.8397
# Epoch 128/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0421 - accuracy: 0.9811 - val_loss: 8.3142 - val_accuracy: 0.8387
# Epoch 129/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0387 - accuracy: 0.9830 - val_loss: 8.3915 - val_accuracy: 0.8340
# Epoch 130/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0623 - accuracy: 0.9789 - val_loss: 7.7923 - val_accuracy: 0.8340
# Epoch 131/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0505 - accuracy: 0.9770 - val_loss: 7.9310 - val_accuracy: 0.8383
# Epoch 132/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0464 - accuracy: 0.9783 - val_loss: 8.4704 - val_accuracy: 0.8437
# Epoch 133/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0502 - accuracy: 0.9806 - val_loss: 7.9860 - val_accuracy: 0.8410
# Epoch 134/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0402 - accuracy: 0.9801 - val_loss: 8.6058 - val_accuracy: 0.8387
# Epoch 135/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0470 - accuracy: 0.9813 - val_loss: 8.1133 - val_accuracy: 0.8330
# Epoch 136/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0447 - accuracy: 0.9801 - val_loss: 8.6299 - val_accuracy: 0.8340
# Epoch 137/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0565 - accuracy: 0.9794 - val_loss: 8.6233 - val_accuracy: 0.8337
# Epoch 138/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0444 - accuracy: 0.9814 - val_loss: 8.7815 - val_accuracy: 0.8333
# Epoch 139/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0382 - accuracy: 0.9826 - val_loss: 9.0128 - val_accuracy: 0.8363
# Epoch 140/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0504 - accuracy: 0.9783 - val_loss: 8.7646 - val_accuracy: 0.8380
# Epoch 141/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0386 - accuracy: 0.9827 - val_loss: 8.9453 - val_accuracy: 0.8363
# Epoch 142/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0575 - accuracy: 0.9797 - val_loss: 8.5219 - val_accuracy: 0.8297
# Epoch 143/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0426 - accuracy: 0.9816 - val_loss: 9.2124 - val_accuracy: 0.8307
# Epoch 144/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0444 - accuracy: 0.9824 - val_loss: 8.8442 - val_accuracy: 0.8290
# Epoch 145/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0443 - accuracy: 0.9799 - val_loss: 9.3051 - val_accuracy: 0.8353
# Epoch 146/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0490 - accuracy: 0.9810 - val_loss: 8.8345 - val_accuracy: 0.8313
# Epoch 147/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0440 - accuracy: 0.9800 - val_loss: 9.0296 - val_accuracy: 0.8300
# Epoch 148/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0410 - accuracy: 0.9810 - val_loss: 9.4568 - val_accuracy: 0.8277
# Epoch 149/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0463 - accuracy: 0.9783 - val_loss: 9.5599 - val_accuracy: 0.8297
# Epoch 150/200
# 700/700 [==============================] - 7s 10ms/step - loss: 0.0477 - accuracy: 0.9754 - val_loss: 10.0944 - val_accuracy: 0.8280
# Epoch 151/200
# 700/700 [==============================] - 7s 9ms/step - loss: 0.0480 - accuracy: 0.9799 - val_loss: 9.6205 - val_accuracy: 0.8323
# Epoch 152/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0449 - accuracy: 0.9781 - val_loss: 9.8012 - val_accuracy: 0.8307
# Epoch 153/200
# 700/700 [==============================] - 7s 9ms/step - loss: 0.0450 - accuracy: 0.9827 - val_loss: 9.9853 - val_accuracy: 0.8357
# Epoch 154/200
# 700/700 [==============================] - 7s 10ms/step - loss: 0.0406 - accuracy: 0.9820 - val_loss: 9.9075 - val_accuracy: 0.8317
# Epoch 155/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0420 - accuracy: 0.9811 - val_loss: 10.4818 - val_accuracy: 0.8343
# Epoch 156/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0376 - accuracy: 0.9839 - val_loss: 10.8416 - val_accuracy: 0.8347
# Epoch 157/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0447 - accuracy: 0.9830 - val_loss: 10.9357 - val_accuracy: 0.8340
# Epoch 158/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0522 - accuracy: 0.9784 - val_loss: 10.2521 - val_accuracy: 0.8340
# Epoch 159/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0456 - accuracy: 0.9793 - val_loss: 10.8237 - val_accuracy: 0.8363
# Epoch 160/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0453 - accuracy: 0.9779 - val_loss: 10.8741 - val_accuracy: 0.8383
# Epoch 161/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0431 - accuracy: 0.9801 - val_loss: 10.8140 - val_accuracy: 0.8350
# Epoch 162/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0473 - accuracy: 0.9797 - val_loss: 10.6734 - val_accuracy: 0.8340
# Epoch 163/200
# 700/700 [==============================] - 7s 9ms/step - loss: 0.0419 - accuracy: 0.9823 - val_loss: 10.9880 - val_accuracy: 0.8357
# Epoch 164/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0380 - accuracy: 0.9837 - val_loss: 11.1442 - val_accuracy: 0.8357
# Epoch 165/200
# 700/700 [==============================] - 7s 9ms/step - loss: 0.0464 - accuracy: 0.9814 - val_loss: 10.8805 - val_accuracy: 0.8327
# Epoch 166/200
# 700/700 [==============================] - 7s 9ms/step - loss: 0.0392 - accuracy: 0.9826 - val_loss: 11.4058 - val_accuracy: 0.8373
# Epoch 167/200
# 700/700 [==============================] - 7s 9ms/step - loss: 0.0561 - accuracy: 0.9789 - val_loss: 10.3948 - val_accuracy: 0.8353
# Epoch 168/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0438 - accuracy: 0.9811 - val_loss: 10.8076 - val_accuracy: 0.8357
# Epoch 169/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0447 - accuracy: 0.9814 - val_loss: 11.0688 - val_accuracy: 0.8363
# Epoch 170/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0412 - accuracy: 0.9834 - val_loss: 11.1180 - val_accuracy: 0.8343
# Epoch 171/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0445 - accuracy: 0.9803 - val_loss: 11.1592 - val_accuracy: 0.8320
# Epoch 172/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0484 - accuracy: 0.9789 - val_loss: 10.4769 - val_accuracy: 0.8330
# Epoch 173/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0446 - accuracy: 0.9824 - val_loss: 11.1043 - val_accuracy: 0.8297
# Epoch 174/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0461 - accuracy: 0.9777 - val_loss: 11.6035 - val_accuracy: 0.8360
# Epoch 175/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0389 - accuracy: 0.9836 - val_loss: 11.9165 - val_accuracy: 0.8317
# Epoch 176/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0435 - accuracy: 0.9830 - val_loss: 12.0033 - val_accuracy: 0.8333
# Epoch 177/200
# 700/700 [==============================] - 7s 9ms/step - loss: 0.0433 - accuracy: 0.9791 - val_loss: 12.7213 - val_accuracy: 0.8313
# Epoch 178/200
# 700/700 [==============================] - 7s 10ms/step - loss: 0.0609 - accuracy: 0.9807 - val_loss: 12.1490 - val_accuracy: 0.8310
# Epoch 179/200
# 700/700 [==============================] - 7s 10ms/step - loss: 0.0420 - accuracy: 0.9801 - val_loss: 12.0909 - val_accuracy: 0.8333
# Epoch 180/200
# 700/700 [==============================] - 8s 11ms/step - loss: 0.0414 - accuracy: 0.9826 - val_loss: 12.4982 - val_accuracy: 0.8317
# Epoch 181/200
# 700/700 [==============================] - 7s 10ms/step - loss: 0.0446 - accuracy: 0.9800 - val_loss: 12.9576 - val_accuracy: 0.8317
# Epoch 182/200
# 700/700 [==============================] - 7s 10ms/step - loss: 0.0374 - accuracy: 0.9821 - val_loss: 13.6746 - val_accuracy: 0.8303
# Epoch 183/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0417 - accuracy: 0.9851 - val_loss: 13.4936 - val_accuracy: 0.8303
# Epoch 184/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0512 - accuracy: 0.9793 - val_loss: 13.2066 - val_accuracy: 0.8287
# Epoch 185/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0456 - accuracy: 0.9827 - val_loss: 13.7033 - val_accuracy: 0.8297
# Epoch 186/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0527 - accuracy: 0.9807 - val_loss: 12.9128 - val_accuracy: 0.8313
# Epoch 187/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0467 - accuracy: 0.9807 - val_loss: 12.7642 - val_accuracy: 0.8307
# Epoch 188/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0453 - accuracy: 0.9813 - val_loss: 13.3205 - val_accuracy: 0.8307
# Epoch 189/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0461 - accuracy: 0.9833 - val_loss: 12.8545 - val_accuracy: 0.8330
# Epoch 190/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0430 - accuracy: 0.9840 - val_loss: 13.1779 - val_accuracy: 0.8317
# Epoch 191/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0536 - accuracy: 0.9803 - val_loss: 12.4950 - val_accuracy: 0.8310
# Epoch 192/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0526 - accuracy: 0.9771 - val_loss: 12.4987 - val_accuracy: 0.8247
# Epoch 193/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0475 - accuracy: 0.9803 - val_loss: 13.2155 - val_accuracy: 0.8270
# Epoch 194/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0555 - accuracy: 0.9810 - val_loss: 13.2284 - val_accuracy: 0.8260
# Epoch 195/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0450 - accuracy: 0.9803 - val_loss: 13.1286 - val_accuracy: 0.8253
# Epoch 196/200
# 700/700 [==============================] - 7s 9ms/step - loss: 0.0524 - accuracy: 0.9804 - val_loss: 12.8849 - val_accuracy: 0.8257
# Epoch 197/200
# 700/700 [==============================] - 6s 9ms/step - loss: 0.0529 - accuracy: 0.9800 - val_loss: 13.5112 - val_accuracy: 0.8307
# Epoch 198/200
# 700/700 [==============================] - 7s 9ms/step - loss: 0.0416 - accuracy: 0.9831 - val_loss: 13.3192 - val_accuracy: 0.8307
# Epoch 199/200
# 700/700 [==============================] - 7s 9ms/step - loss: 0.0495 - accuracy: 0.9814 - val_loss: 12.3927 - val_accuracy: 0.8257
# Epoch 200/200
# 700/700 [==============================] - 7s 9ms/step - loss: 0.0388 - accuracy: 0.9820 - val_loss: 13.3103 - val_accuracy: 0.8310

# %%
model.save('/content/drive/MyDrive/Colab Notebooks/Kerasmodel')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/Kerasmodel/assets

# %%
model_score = model.evaluate(X1_test, Y1_test, batch_size=20, verbose=1)
print("Test accuracy:", model_score[1])
# Out:
# 150/150 [==============================] - 1s 4ms/step - loss: 13.3103 - accuracy: 0.8310
# Test accuracy: 0.8309999704360962

# %%
preds = model.predict(X1_test)

dfp = pd.DataFrame (preds)
dfp
# Out:
#                  0             1             2
# 0     0.000000e+00  0.000000e+00  1.000000e+00
# 1     0.000000e+00  0.000000e+00  1.000000e+00
# 2     7.302937e-24  0.000000e+00  1.000000e+00
# 3     1.000000e+00  0.000000e+00  0.000000e+00
# 4     4.242858e-01  4.600598e-01  1.156545e-01
# ...            ...           ...           ...
# 2995  1.427244e-26  0.000000e+00  1.000000e+00
# 2996  1.000000e+00  6.703215e-16  9.404122e-11
# 2997  4.421395e-20  0.000000e+00  1.000000e+00
# 2998  1.000000e+00  6.937813e-27  3.982838e-18
# 2999  1.066847e-10  1.000000e+00  6.907465e-21
#
# [3000 rows x 3 columns]

# %%
news_model = tf.keras.models.load_model('/content/drive/MyDrive/Colab Notebooks/Kerasmodel/')

# %%
predss = model.predict (X2)
predss
# Out:
# array([[9.9992096e-01, 1.9140269e-07, 7.8789992e-05],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#        [1.0000000e+00, 0.0000000e+00, 0.0000000e+00],
#        ...,
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00],
#        [1.1588034e-31, 0.0000000e+00, 1.0000000e+00],
#        [0.0000000e+00, 0.0000000e+00, 1.0000000e+00]], dtype=float32)

# %%
DFN = np.c_[X3, Y2, predss]

dfz = pd.DataFrame (DFN)
dfz
# Out:
#                                                      0  ...          6
# 0    cheetah fastest land animal can run 70 miles hour  ...  7.879e-05
# 1    group of words which makes complete sense is c...  ...          0
# 2                   little hello and kiss from our son  ...          0
# 3    According to this article volcanoes in Auvergn...  ...          1
# 4    After long hot night we spent together I feel ...  ...          0
# ..                                                 ...  ...        ...
# 988                       I am only doing this for you  ...          1
# 989                             You should go out more  ...          1
# 990  You think you dont need anyone but in fact you...  ...          1
# 991                         I love you as big as truck  ...          1
# 992                          Wow youre really annoying  ...          1
#
# [993 rows x 7 columns]

# %%
dfz.to_csv(r'/content/drive/MyDrive/final_table6.csv', index = False)
